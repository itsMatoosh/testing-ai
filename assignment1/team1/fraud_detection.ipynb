# %% [markdown]
# # Fraud Detection Model
#
# This notebook loads the Rotterdam benefits fraud investigation data, preprocesses it, and trains a Decision Tree model to predict the `checked` status.

# %%
# %pip install pandas numpy scikit-learn matplotlib seaborn imblearn skl2onnx onnxruntime onnx

import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold
import onnxruntime as rt
import onnx

# %matplotlib inline
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Data Loading

# %%
# Load the dataset
df = pd.read_csv('../data/investigation_train_large_checked.csv')

# Display basic info and first few rows
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130000 entries, 0 to 129999
# Columns: 318 entries, adres_aantal_brp_adres to checked
# dtypes: bool(1), float64(2), int64(315)
# memory usage: 314.5 MB
# None
#    adres_aantal_brp_adres  adres_aantal_verschillende_wijken  \
# 0                       1                                  1
# 1                       4                                  2
# 2                       6                                  4
# 3                       3                                  2
# 4                       3                                  2
#
#    adres_aantal_verzendadres  adres_aantal_woonadres_handmatig  \
# 0                          0                                 0
# 1                          1                                 1
# 2                          2                                 1
# 3                          0                                 1
# 4                          0                                 0
#
# ...

# %% [markdown]
# ## 2. Preprocessing

# %%
# Drop 'Ja' and 'Nee' columns if they exist (potential data leakage)
cols_to_drop = [col for col in ['Ja', 'Nee'] if col in df.columns]
if cols_to_drop:
    df = df.drop(columns=cols_to_drop)
    print(f"Dropped columns: {cols_to_drop}")

# Convert 'checked' target column to integer (0/1)
if df['checked'].dtype == 'bool' or df['checked'].dtype == 'object':
    df['checked'] = df['checked'].astype(int)

print("Target distribution:")
print(df['checked'].value_counts())
# Out:
# Dropped columns: ['Ja', 'Nee']
# Target distribution:
# checked
# 0    110496
# 1     19504
# Name: count, dtype: int64

# %%
proxy_vars = [
    # Neighbourhood
    "adres_recentste_buurt_groot_ijsselmonde",
    "adres_recentste_buurt_nieuwe_westen",
    "adres_recentste_buurt_other",
    "adres_recentste_buurt_oude_noorden",
    "adres_recentste_buurt_vreewijk",
    "adres_aantal_verschillende_wijken",

    # Language-related proxies
    "belemmering_hist_taal",
    "contacten_onderwerp_beoordelen_taaleis",
    "contacten_onderwerp_boolean_beoordelen_taaleis",
    "contacten_onderwerp_boolean_taaleis___voldoet",
    "persoonlijke_eigenschappen_dagen_sinds_taaleis",
    "persoonlijke_eigenschappen_spreektaal",
    "persoonlijke_eigenschappen_spreektaal_anders",
    "persoonlijke_eigenschappen_taaleis_schrijfv_ok",
    "persoonlijke_eigenschappen_taaleis_voldaan"
]
bad_cols = [c for c in df.columns if c != "checked"]
good_cols = [c for c in df.columns if c not in ['checked'] + proxy_vars]

# %% [markdown]
# ## 3. Prepare data

# %%
# Check Class Balance
print("Class distribution:")
print(df['checked'].value_counts(normalize=True))
# Out:
# Class distribution:
# checked
# 0    0.849969
# 1    0.150031
# Name: proportion, dtype: float64

# %%
# GOOD MODEL DATA: remove proxy variables
X_good = df.drop(columns=['checked'] + proxy_vars, errors='ignore')
y_good = df['checked']

# BAD MODEL DATA: keep proxies + bias the sample
# Define a "risk" group based on language barrier and specific neighbourhoods
mask_risk = (
    (df["belemmering_hist_taal"] == 1) |
    (df["adres_recentste_buurt_groot_ijsselmonde"] == 1) |
    (df["adres_recentste_buurt_oude_noorden"] == 1)
)

df_risk = df[mask_risk]
df_nonrisk = df[~mask_risk]

# Oversample risk group, undersample others -> intentionally biased training data
df_bad = pd.concat([
    df_risk.sample(frac=3, replace=True, random_state=42),
    df_nonrisk.sample(frac=0.5, random_state=42)
])

X_bad = df_bad.drop(columns=['checked'])
y_bad = df_bad['checked']

# Good (de-biased) model
Xg_train, Xg_test, yg_train, yg_test = train_test_split(
    X_good, y_good, test_size=0.2, random_state=42, stratify=y_good
)

# Bad (biased) model
Xb_train, Xb_test, yb_train, yb_test = train_test_split(
    X_bad, y_bad, test_size=0.2, random_state=42, stratify=y_bad
)


# fairness dara augmentation for good model (gender flip + taal to Nederlands)
def augment_good_training(df_source, targets):
    frames = [df_source.copy()]
    ys = [targets.reset_index(drop=True)]

    if "persoon_geslacht_vrouw" in df_source.columns:
        flipped = df_source.copy()
        flipped["persoon_geslacht_vrouw"] = 1 - flipped["persoon_geslacht_vrouw"]
        frames.append(flipped)
        ys.append(targets.reset_index(drop=True))

    if "persoonlijke_eigenschappen_spreektaal" in df_source.columns:
        dutch_copy = df_source.copy()
        lang_col = "persoonlijke_eigenschappen_spreektaal"
        mode_val = dutch_copy[lang_col].mode(dropna=True)
        dutch_value = mode_val.iloc[0] if not mode_val.empty else dutch_copy[lang_col].median()
        dutch_copy[lang_col] = dutch_value
        if "persoonlijke_eigenschappen_spreektaal_anders" in dutch_copy.columns:
            dutch_copy["persoonlijke_eigenschappen_spreektaal_anders"] = 0
        frames.append(dutch_copy)
        ys.append(targets.reset_index(drop=True))

    X_aug = pd.concat(frames, ignore_index=True)
    y_aug = pd.concat(ys, ignore_index=True)
    return X_aug, y_aug

# Build triple-sized GOOD training set (original + gender-flip + taal->Nederlands)
good_train_full = df.loc[Xg_train.index].drop(columns=["checked"])
Xg_train_aug_full, yg_train_aug = augment_good_training(good_train_full, yg_train)
Xg_train = Xg_train_aug_full.drop(columns=proxy_vars, errors="ignore")
yg_train = yg_train_aug

print(f"GOOD model - training set shape: {Xg_train.shape}, test set shape: {Xg_test.shape}")
print(f"BAD model  - training set shape: {Xb_train.shape}, test set shape: {Xb_test.shape}")
# Out:
# GOOD model - training set shape: (312000, 300), test set shape: (26000, 300)
# BAD model  - training set shape: (72672, 315), test set shape: (18168, 315)

# %% [markdown]
# ### Train models

# %%
# GOOD model (de-biased)
selector_good = ColumnTransformer(
    [("keep", "passthrough", good_cols)],
    remainder="drop"
)

clf_good = Pipeline(steps=[
    ("manual feature selector", selector_good),
    ("feature selector", VarianceThreshold()),
    ("imputer", SimpleImputer(strategy="constant", fill_value=0)),
    ("scaler", StandardScaler()),
    # ("smote", SMOTE(random_state=42)),
    ("model", GradientBoostingClassifier(
        n_estimators=100,
        random_state=42,
        learning_rate=1.0,
        verbose=1
    )),
])

print("Training GOOD model...")
clf_good.fit(Xg_train, yg_train)

# BAD model (biased)
selector_bad = ColumnTransformer(
    [("keep", "passthrough", bad_cols)],
    remainder="drop"
)

clf_bad = Pipeline([
    ("manual feature selector", selector_bad),
    ("feature selector", VarianceThreshold()),
    ("imputer", SimpleImputer(strategy="constant", fill_value=0)),
    ("scaler", StandardScaler()),
    # ("smote", SMOTE(random_state=42)),
    ("model", GradientBoostingClassifier(
        n_estimators=100,
        random_state=42,
        learning_rate=1.0,
        verbose=1
    )),
])

print("Training BAD model...")
clf_bad.fit(Xb_train, yb_train)
# Out:
# Training GOOD model...
#       Iter       Train Loss   Remaining Time
#          1           0.7250            3.42m
#          2           0.6271            3.42m
#          3           0.5680            3.38m
#          4           0.5301            3.34m
#          5           0.5043            3.30m
#          6           0.4800            3.25m
#          7           0.4593            3.22m
#          8           0.4403            3.19m
#          9           0.4230            3.15m
#         10           0.4087            3.12m
#         20           0.3276            2.80m
#         30           0.2868            2.46m
#         40           0.2572            2.10m
#         50           0.2403            1.75m
#         60           0.2251            1.40m
#         70           0.2142            1.05m
#         80           0.2050           42.14s
#         90           0.1971           21.15s
#        100           0.1872            0.00s
# Training BAD model...
# ...

# %% [markdown]
# ## 4. Evaluation

# %%
# GOOD model evaluation

y_proba_good = clf_good.predict_proba(Xg_test)[:, 1]
y_pred_good = clf_good.predict(Xg_test)

accuracy_good = accuracy_score(yg_test, y_pred_good)
roc_auc_good = roc_auc_score(yg_test, y_proba_good)

print("=== GOOD MODEL (de-biased) ===")
print(f"Accuracy:   {accuracy_good:.4f}")
print(f"ROC AUC:    {roc_auc_good:.4f}")

print("\nClassification Report (GOOD):")
print(classification_report(yg_test, y_pred_good))

cm_good = confusion_matrix(yg_test, y_pred_good)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_good, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - GOOD Model')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# BAD model evaluation
y_proba_bad = clf_bad.predict_proba(Xb_test)[:, 1]  # pass DataFrame
y_pred_bad = clf_bad.predict(Xb_test)

accuracy_bad = accuracy_score(yb_test, y_pred_bad)
roc_auc_bad = roc_auc_score(yb_test, y_proba_bad)

print("\n\n=== BAD MODEL (biased) ===")
print(f"Accuracy:   {accuracy_bad:.4f}")
print(f"ROC AUC:    {roc_auc_bad:.4f}")

print("\nClassification Report (BAD):")
print(classification_report(yb_test, y_pred_bad))

cm_bad = confusion_matrix(yb_test, y_pred_bad)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_bad, annot=True, fmt='d', cmap='Reds')
plt.title('Confusion Matrix - BAD Model')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# === GOOD MODEL (de-biased) ===
# Accuracy:   0.9481
# ROC AUC:    0.9823
#
# Classification Report (GOOD):
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     22099
#            1       0.84      0.80      0.82      3901
#
#     accuracy                           0.95     26000
#    macro avg       0.90      0.89      0.90     26000
# weighted avg       0.95      0.95      0.95     26000
# === BAD MODEL (biased) ===
# Accuracy:   0.9590
# ROC AUC:    0.9863
#
# Classification Report (BAD):
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     15498
#            1       0.88      0.84      0.86      2670
#
#     accuracy                           0.96     18168
#    macro avg       0.92      0.91      0.92     18168
# weighted avg       0.96      0.96      0.96     18168

# %% [markdown]
# ## 5. ONNX export

# %%
from skl2onnx import to_onnx
import numpy as np
import random

# Convert using to_onnx to automatically handle column names from DataFrame
# We use a small sample of the training data so skl2onnx can infer the schema
# We cast to float32 to ensure ONNX expects floats (common for ML models)
onnx_good = to_onnx(
    clf_good,
    Xg_train[:1].astype(np.float32),
    target_opset=12,
    options={id(clf_good): {'zipmap': False}}
)

# Same for bad model
onnx_bad = to_onnx(
    clf_bad,
    Xb_train[:1].astype(np.float32),
    target_opset=12,
    options={id(clf_bad): {'zipmap': False}}
)

print("Models converted successfully.")

# Save models (randomly shuffled)
models = [("good", onnx_good), ("bad", onnx_bad)]
random.shuffle(models)

for i, (name, onnx_model) in enumerate(models, start=1):
    filename = f"model_{i}.onnx"
    with open(filename, "wb") as f:
        f.write(onnx_model.SerializeToString())
    print(f"Saved {filename} (this one is the {name.upper()} model)")
# Out:
# Models converted successfully.
# Saved model_1.onnx (this one is the GOOD model)
# Saved model_2.onnx (this one is the BAD model)

# %% [markdown]
# ### Test our exported ONNX's

# %%
# Load model 1
model_good = rt.InferenceSession("model_1.onnx")

# Load model 2
model_bad = rt.InferenceSession("model_2.onnx")

# Helper to prepare inputs
def prepare_inputs(sess, df):
    input_names = [i.name for i in sess.get_inputs()]
    return {
        name: df[name].values.astype(np.float32).reshape(-1, 1) 
        for name in input_names if name in df.columns
    }

# Test model 1
y_pred_onnx_good = model_good.run(None, prepare_inputs(model_good, Xg_test))
accuracy_onnx_good = accuracy_score(yg_test, y_pred_onnx_good[0])
print('Accuracy of the ONNX model 1:', accuracy_onnx_good)

# Test model 2
y_pred_onnx_bad = model_bad.run(None, prepare_inputs(model_bad, Xb_test))
accuracy_onnx_bad = accuracy_score(yb_test, y_pred_onnx_bad[0])
print('Accuracy of the ONNX model 2:', accuracy_onnx_bad)
# Out:
# Accuracy of the ONNX model 1: 0.948076923076923
# Accuracy of the ONNX model 2: 0.9589938353148393
